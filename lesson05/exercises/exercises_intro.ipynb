# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #### In this exercises session, you will continue with the bike dataset. Please load it first.

# %%
#How do I work with dates and times in pandas?: https://www.youtube.com/watch?v=yCgJGsg0Xa4
#
df = pd.read_csv("../data/bikesharing/data.csv", sep=",")
df
# Out:
#                  timestamp   cnt   t1   t2    hum  wind_speed  weather_code  \
# 0      2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 1      2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2      2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 3      2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 4      2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                    ...   ...  ...  ...    ...         ...           ...
# 17409  2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 17410  2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 17411  2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 17412  2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 17413  2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#        is_holiday  is_weekend  season
# 0             0.0         1.0     3.0
# 1             0.0         1.0     3.0
# 2             0.0         1.0     3.0
# 3             0.0         1.0     3.0
# 4             0.0         1.0     3.0
# ...           ...         ...     ...
# 17409         0.0         0.0     3.0
# 17410         0.0         0.0     3.0
# 17411         0.0         0.0     3.0
# 17412         0.0         0.0     3.0
# 17413         0.0         0.0     3.0
#
# [17414 rows x 10 columns]

# %% [markdown]
# #### Convert the "timestamp" column to an actual timestamp. With the first timestamp in the list, find 2 new members and 2 new members functions. Hint: after typing the dot "." click a "Tab" and explore the list.

# %%
ts=df.loc[0,"timestamp"]
type(ts)
# Out:
# str

# %%
ts_pd=pd.to_datetime(ts, format="%Y-%m-%d %H:%M:%S")
ts_pd
# Out:
# Timestamp('2015-01-04 00:00:00')

# %%
type(ts_pd)
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df["timestamp"].apply(lambda x: pd.to_datetime(x, format="%Y-%m-%d %H:%M:%S"))
# Out:
# 0       2015-01-04 00:00:00
# 1       2015-01-04 01:00:00
# 2       2015-01-04 02:00:00
# 3       2015-01-04 03:00:00
# 4       2015-01-04 04:00:00
#                 ...
# 17409   2017-01-03 19:00:00
# 17410   2017-01-03 20:00:00
# 17411   2017-01-03 21:00:00
# 17412   2017-01-03 22:00:00
# 17413   2017-01-03 23:00:00
# Name: timestamp, Length: 17414, dtype: datetime64[ns]

# %%
df["timestamp"]=pd.to_datetime(df["timestamp"], format="%Y-%m-%d %H:%M:%S")
df
# Out:
#                 timestamp   cnt   t1   t2    hum  wind_speed  weather_code  \
# 0     2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 1     2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2     2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 3     2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 4     2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                   ...   ...  ...  ...    ...         ...           ...
# 17409 2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 17410 2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 17411 2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 17412 2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 17413 2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#        is_holiday  is_weekend  season
# 0             0.0         1.0     3.0
# 1             0.0         1.0     3.0
# 2             0.0         1.0     3.0
# 3             0.0         1.0     3.0
# 4             0.0         1.0     3.0
# ...           ...         ...     ...
# 17409         0.0         0.0     3.0
# 17410         0.0         0.0     3.0
# 17411         0.0         0.0     3.0
# 17412         0.0         0.0     3.0
# 17413         0.0         0.0     3.0
#
# [17414 rows x 10 columns]

# %%
ts=df.loc[0,"timestamp"]
type(ts)
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17414 entries, 0 to 17413
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   timestamp     17414 non-null  datetime64[ns]
#  1   cnt           17414 non-null  int64
#  2   t1            17414 non-null  float64
#  3   t2            17414 non-null  float64
#  4   hum           17414 non-null  float64
#  5   wind_speed    17414 non-null  float64
#  6   weather_code  17414 non-null  float64
#  7   is_holiday    17414 non-null  float64
#  8   is_weekend    17414 non-null  float64
#  9   season        17414 non-null  float64
# dtypes: datetime64[ns](1), float64(8), int64(1)
# memory usage: 1.3 MB

# %% [markdown]
# #### How many full weeks does this dataset cover? (a full week meaning from Monday to Sunday)

# %%
df["weekday"] = df.timestamp.dt.day_name()
df["hour"] = df.timestamp.dt.hour
df
# Out:
#                 timestamp   cnt   t1   t2    hum  wind_speed  weather_code  \
# 0     2015-01-04 00:00:00   182  3.0  2.0   93.0         6.0           3.0
# 1     2015-01-04 01:00:00   138  3.0  2.5   93.0         5.0           1.0
# 2     2015-01-04 02:00:00   134  2.5  2.5   96.5         0.0           1.0
# 3     2015-01-04 03:00:00    72  2.0  2.0  100.0         0.0           1.0
# 4     2015-01-04 04:00:00    47  2.0  0.0   93.0         6.5           1.0
# ...                   ...   ...  ...  ...    ...         ...           ...
# 17409 2017-01-03 19:00:00  1042  5.0  1.0   81.0        19.0           3.0
# 17410 2017-01-03 20:00:00   541  5.0  1.0   81.0        21.0           4.0
# 17411 2017-01-03 21:00:00   337  5.5  1.5   78.5        24.0           4.0
# 17412 2017-01-03 22:00:00   224  5.5  1.5   76.0        23.0           4.0
# 17413 2017-01-03 23:00:00   139  5.0  1.0   76.0        22.0           2.0
#
#        is_holiday  is_weekend  season  weekday  hour
# 0             0.0         1.0     3.0   Sunday     0
# 1             0.0         1.0     3.0   Sunday     1
# 2             0.0         1.0     3.0   Sunday     2
# 3             0.0         1.0     3.0   Sunday     3
# 4             0.0         1.0     3.0   Sunday     4
# ...           ...         ...     ...      ...   ...
# 17409         0.0         0.0     3.0  Tuesday    19
# 17410         0.0         0.0     3.0  Tuesday    20
# 17411         0.0         0.0     3.0  Tuesday    21
# 17412         0.0         0.0     3.0  Tuesday    22
# 17413         0.0         0.0     3.0  Tuesday    23
#
# [17414 rows x 12 columns]

# %%
#from datetime import datetime
##from datetime import date
#df['timestamp'].isocalendar()[
df.isocalendar()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-09e244bc01b3> in <module>
#       2 ##from datetime import date
#       3 #df['timestamp'].isocalendar()[
# ----> 4 df.isocalendar()
#
# c:\python39\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5464                 return self[name]
# -> 5465             return object.__getattribute__(self, name)
#    5466
#    5467     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'isocalendar'

# %% [markdown]
# #### What was the maximum temperature (column: t1) recorded on a Friday night (between 10p.m. and 6a.m.)?

# %% [markdown]
# #### Try to figure out what the single values of the column: weather_code mean. Create a new column which contains names of the seasons.

# %% [markdown]
# #### What was the average number of bike rides in winter? How was the number in the summer? What can you say about these numbers and is a direct comparison the right thing to do? Why? Why not?
