# %% [markdown]
# #### Hi! Today you will play with NaN values and another Data Manipulation methods. Let us know if you need help and also if you need more challenges on that :)

# %% [markdown]
# #### The dataset that you will use is again recipes.csv. You can either use your own or the one in the subfolder "data". Do not forget to import the necessary libraries!

# %%
import numpy as np
import pandas as pd

#df = pd.read_csv("data\\recipes.csv", index_col = 1) 
df = pd.read_csv("data\\recipes.csv", parse_dates=["title"])
df.set_index('title', inplace = True)
df
# Out:
#                                                    Unnamed: 0  vegetarian  \
# title
# Banana Blueberry Pancakes                                   0        True
# Basil and Orange Confit Compound Butter                     1        True
# Black Bottom Banana Bars                                    2       False
# The Best Raw Chocolate Chip Cookies                         3        True
# Mediterranean Spinach Artichoke Dip                         4       False
# ...                                                       ...         ...
# Chicken Sausage, White Bean and Cabbage Soup              145       False
# Pinot Noir Brownies                                       146        True
# Cauliflower Chickpea Stew                                 147        True
# Sautéed Balsamic Green Beans With Cherry Tomatoes         148        True
# Indian-Style Dill and Turmeric Potato Salad               149        True
#
#                                                    glutenFree  dairyFree  \
# title
# Banana Blueberry Pancakes                                True       True
# Basil and Orange Confit Compound Butter                  True      False
# Black Bottom Banana Bars                                False      False
# The Best Raw Chocolate Chip Cookies                     False       True
# Mediterranean Spinach Artichoke Dip                      True      False
# ...                                                       ...        ...
# Chicken Sausage, White Bean and Cabbage Soup             True       True
# Pinot Noir Brownies                                     False      False
# Cauliflower Chickpea Stew                                True       True
# Sautéed Balsamic Green Beans With Cherry Tomatoes        True      False
# Indian-Style Dill and Turmeric Potato Salad              True       True
#
#                                                    veryHealthy  healthScore  \
# title
# Banana Blueberry Pancakes                                False          1.0
# Basil and Orange Confit Compound Butter                  False          0.0
# Black Bottom Banana Bars                                 False          3.0
# The Best Raw Chocolate Chip Cookies                      False          2.0
# Mediterranean Spinach Artichoke Dip                      False         31.0
# ...                                                        ...          ...
# Chicken Sausage, White Bean and Cabbage Soup             False         18.0
# Pinot Noir Brownies                                      False          1.0
# Cauliflower Chickpea Stew                                 True         93.0
# Sautéed Balsamic Green Beans With Cherry Tomatoes        False          5.0
# Indian-Style Dill and Turmeric Potato Salad               True        100.0
#
#                                                    aggregateLikes      id  \
# title
# Banana Blueberry Pancakes                                       3  633998
# Basil and Orange Confit Compound Butter                         1  634426
# Black Bottom Banana Bars                                        1  635085
# The Best Raw Chocolate Chip Cookies                             1  663229
# Mediterranean Spinach Artichoke Dip                             3  651437
# ...                                                           ...     ...
# Chicken Sausage, White Bean and Cabbage Soup                   13  638315
# Pinot Noir Brownies                                             2  656248
# Cauliflower Chickpea Stew                                       2  637297
# Sautéed Balsamic Green Beans With Cherry Tomatoes               1  659412
# Indian-Style Dill and Turmeric Potato Salad                     4  647875
#
#                                                    pricePerServing  \
# title
# Banana Blueberry Pancakes                                    55.79
# Basil and Orange Confit Compound Butter                      15.07
# Black Bottom Banana Bars                                     78.85
# The Best Raw Chocolate Chip Cookies                          54.64
# Mediterranean Spinach Artichoke Dip                         115.26
# ...                                                            ...
# Chicken Sausage, White Bean and Cabbage Soup                196.23
# Pinot Noir Brownies                                          65.76
# Cauliflower Chickpea Stew                                   139.28
# Sautéed Balsamic Green Beans With Cherry Tomatoes           101.81
# Indian-Style Dill and Turmeric Potato Salad                 117.24
# Sautéed Balsamic Green Beans With Cherry Tomatoes          55.64
# Indian-Style Dill and Turmeric Potato Salad                27.96
#
#                                                    CalciumpercentOfDailyNeed  \
# title
# Banana Blueberry Pancakes                                               1.81
# Basil and Orange Confit Compound Butter                                  NaN
# Black Bottom Banana Bars                                               10.08
# The Best Raw Chocolate Chip Cookies                                     2.68
# Mediterranean Spinach Artichoke Dip                                    16.28
# ...                                                                      ...
# Chicken Sausage, White Bean and Cabbage Soup                           10.27
# Pinot Noir Brownies                                                     1.98
# Cauliflower Chickpea Stew                                              14.12
# Sautéed Balsamic Green Beans With Cherry Tomatoes                       5.56
# Indian-Style Dill and Turmeric Potato Salad                             2.80
#
#                                                    AlcoholAmount  \
# title
# Banana Blueberry Pancakes                                    NaN
# Basil and Orange Confit Compound Butter                      NaN
# Black Bottom Banana Bars                                    0.28
# The Best Raw Chocolate Chip Cookies                          NaN
# Mediterranean Spinach Artichoke Dip                          NaN
# ...                                                          ...
# Chicken Sausage, White Bean and Cabbage Soup                 NaN
# Pinot Noir Brownies                                         2.48
# Cauliflower Chickpea Stew                                    NaN
# Sautéed Balsamic Green Beans With Cherry Tomatoes            NaN
# Indian-Style Dill and Turmeric Potato Salad                  NaN
#
#                                                    AlcoholpercentOfDailyNeed  \
# title
# Banana Blueberry Pancakes                                                NaN
# Basil and Orange Confit Compound Butter                                  NaN
# Black Bottom Banana Bars                                                1.53
# The Best Raw Chocolate Chip Cookies                                      NaN
# Mediterranean Spinach Artichoke Dip                                      NaN
# ...                                                                      ...
# Chicken Sausage, White Bean and Cabbage Soup                             NaN
# Pinot Noir Brownies                                                    13.76
# Cauliflower Chickpea Stew                                                NaN
# Sautéed Balsamic Green Beans With Cherry Tomatoes                        NaN
# Indian-Style Dill and Turmeric Potato Salad                              NaN
#
#                                                    CaffeineAmount  \
# title
# Banana Blueberry Pancakes                                     NaN
# Basil and Orange Confit Compound Butter                       NaN
# Black Bottom Banana Bars                                     9.89
# The Best Raw Chocolate Chip Cookies                           NaN
# Mediterranean Spinach Artichoke Dip                           NaN
# ...                                                           ...
# Chicken Sausage, White Bean and Cabbage Soup                  NaN
# Pinot Noir Brownies                                         10.69
# Cauliflower Chickpea Stew                                     NaN
# Sautéed Balsamic Green Beans With Cherry Tomatoes             NaN
# Indian-Style Dill and Turmeric Potato Salad                   NaN
#
#                                                    CaffeinepercentOfDailyNeed
# title
# Banana Blueberry Pancakes                                                 NaN
# Basil and Orange Confit Compound Butter                                   NaN
# Black Bottom Banana Bars                                                 3.30
# The Best Raw Chocolate Chip Cookies                                       NaN
# Mediterranean Spinach Artichoke Dip                                       NaN
# ...                                                                       ...
# Chicken Sausage, White Bean and Cabbage Soup                              NaN
# Pinot Noir Brownies                                                      3.56
# Cauliflower Chickpea Stew                                                 NaN
# Sautéed Balsamic Green Beans With Cherry Tomatoes                         NaN
# Indian-Style Dill and Turmeric Potato Salad                               NaN
#
# [150 rows x 78 columns]

# %% [markdown]
# #### Print the names of Columns that have null values

# %%
# How to Identify and Drop Null Values | Handling Missing Values in Python: https://www.youtube.com/watch?v=57vFbsiZYHg

df.isnull().head()
# Out:
#                                          Unnamed: 0  vegetarian  glutenFree  \
# title
# Banana Blueberry Pancakes                     False       False       False
# Basil and Orange Confit Compound Butter       False       False       False
# Black Bottom Banana Bars                      False       False       False
# The Best Raw Chocolate Chip Cookies           False       False       False
# Mediterranean Spinach Artichoke Dip           False       False       False
#
#                                          dairyFree  veryHealthy  healthScore  \
# title
# Banana Blueberry Pancakes                    False        False        False
# Basil and Orange Confit Compound Butter      False        False        False
# Black Bottom Banana Bars                     False        False        False
# The Best Raw Chocolate Chip Cookies          False        False        False
# Mediterranean Spinach Artichoke Dip          False        False        False
#
#                                          aggregateLikes     id  \
# title
# Banana Blueberry Pancakes                         False  False
# Basil and Orange Confit Compound Butter           False  False
# Black Bottom Banana Bars                          False  False
# The Best Raw Chocolate Chip Cookies               False  False
# Mediterranean Spinach Artichoke Dip               False  False
#
#                                          pricePerServing  readyInMinutes  ...  \
# title                                                                     ...
# Banana Blueberry Pancakes                          False           False  ...
# Basil and Orange Confit Compound Butter            False           False  ...
# Black Bottom Banana Bars                           False           False  ...
# The Best Raw Chocolate Chip Cookies                False           False  ...
# Mediterranean Spinach Artichoke Dip                False           False  ...
#
#                                          VitaminB3Amount  \
# title
# Banana Blueberry Pancakes                          False
# Basil and Orange Confit Compound Butter             True
# Black Bottom Banana Bars                           False
# The Best Raw Chocolate Chip Cookies                False
# Mediterranean Spinach Artichoke Dip                False
#
#                                          VitaminB3percentOfDailyNeed  \
# title
# Banana Blueberry Pancakes                                      False
# Basil and Orange Confit Compound Butter                         True
# Black Bottom Banana Bars                                       False
# The Best Raw Chocolate Chip Cookies                            False
# Mediterranean Spinach Artichoke Dip                            False
#
#                                          VitaminB1Amount  \
# title
# Banana Blueberry Pancakes                          False
# Basil and Orange Confit Compound Butter             True
# Black Bottom Banana Bars                           False
# The Best Raw Chocolate Chip Cookies                False
# Mediterranean Spinach Artichoke Dip                False
#
#                                          VitaminB1percentOfDailyNeed  \
# title
# Banana Blueberry Pancakes                                      False
# Basil and Orange Confit Compound Butter                         True
# Black Bottom Banana Bars                                       False
# The Best Raw Chocolate Chip Cookies                            False
# Mediterranean Spinach Artichoke Dip                            False
#
#                                          CalciumAmount  \
# title
# Banana Blueberry Pancakes                        False
# Basil and Orange Confit Compound Butter           True
# Black Bottom Banana Bars                         False
# The Best Raw Chocolate Chip Cookies              False
# Mediterranean Spinach Artichoke Dip              False
#
#                                          CalciumpercentOfDailyNeed  \
# title
# Banana Blueberry Pancakes                                    False
# Basil and Orange Confit Compound Butter                       True
# Black Bottom Banana Bars                                     False
# The Best Raw Chocolate Chip Cookies                          False
# Mediterranean Spinach Artichoke Dip                          False
#
#                                          AlcoholAmount  \
# title
# Banana Blueberry Pancakes                         True
# Basil and Orange Confit Compound Butter           True
# Black Bottom Banana Bars                         False
# The Best Raw Chocolate Chip Cookies               True
# Mediterranean Spinach Artichoke Dip               True
#
#                                          AlcoholpercentOfDailyNeed  \
# title
# Banana Blueberry Pancakes                                     True
# Basil and Orange Confit Compound Butter                       True
# Black Bottom Banana Bars                                     False
# The Best Raw Chocolate Chip Cookies                           True
# Mediterranean Spinach Artichoke Dip                           True
#
#                                          CaffeineAmount  \
# title
# Banana Blueberry Pancakes                          True
# Basil and Orange Confit Compound Butter            True
# Black Bottom Banana Bars                          False
# The Best Raw Chocolate Chip Cookies                True
# Mediterranean Spinach Artichoke Dip                True
#
#                                          CaffeinepercentOfDailyNeed
# title
# Banana Blueberry Pancakes                                      True
# Basil and Orange Confit Compound Butter                        True
# Black Bottom Banana Bars                                      False
# The Best Raw Chocolate Chip Cookies                            True
# Mediterranean Spinach Artichoke Dip                            True
#
# [5 rows x 78 columns]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0                      0
# vegetarian                      0
# glutenFree                      0
# dairyFree                       0
# veryHealthy                     0
#                              ...
# CalciumpercentOfDailyNeed       8
# AlcoholAmount                 129
# AlcoholpercentOfDailyNeed     129
# CaffeineAmount                141
# CaffeinepercentOfDailyNeed    141
# Length: 78, dtype: int64

# %%
df1 = df.copy()

# %% [markdown]
# #### Print the recipes with the highest number of aggregateLikes

# %%
# Pandas DataFrames: Finding Min/Max Element: https://www.youtube.com/watch?v=C8sPV25PCs0 & 
#https://www.youtube.com/watch?v=fCMrO_VzeL8

df1['aggregateLikes'].idxmax()
# Out:
# 'Slow Cooker Spicy Hot Wings'

# %%
df1['aggregateLikes'][df1['aggregateLikes'].idxmax()]
# Out:
# 16911

# %% [markdown]
# #### Handle the missing values of “calcium percent of Daily need”. Sort the resulting DataFrame by id column.

# %%
print("Number of Column in: ")
for ColName in df1[['CalciumpercentOfDailyNeed']]:
    print("{} = {}".format(ColName,len(df1[ColName].unique())))
    
#https://realpython.com/pandas-sort-python/

df1.sort_values(
by=["CalciumpercentOfDailyNeed", "id"])[["CalciumpercentOfDailyNeed", "id"]]
# Out:
# Number of Column in:
# CalciumpercentOfDailyNeed = 137
#                                                     CalciumpercentOfDailyNeed  \
# title
# White Chocolate Raspberry Brie Cups                                      1.25
# Peanut Butter Cookies with Flax Seeds and Choco...                       1.29
# Mom's Pork Menudo                                                        1.41
# Chicken with Avocado Peach Salsa                                         1.42
# Blueberry Mojito Popsicles                                               1.65
# ...                                                                       ...
# Pandan Thumbprint Biscuits                                                NaN
# Rosewater Lavender Shortbread                                             NaN
# Sundried Tomato,Olive,Rosemary and Thyme Foccac...                        NaN
# Truffle Linguine With Tomatoes and Pancetta                               NaN
# Coconut Flour Muffins                                                     NaN
#
#                                                          id
# title
# White Chocolate Raspberry Brie Cups                  665193
# Peanut Butter Cookies with Flax Seeds and Choco...   655282
# Mom's Pork Menudo                                    652308
# Chicken with Avocado Peach Salsa                     673436
# Blueberry Mojito Popsicles                           635495
# ...                                                     ...
# Pandan Thumbprint Biscuits                           654516
# Rosewater Lavender Shortbread                        658823
# Sundried Tomato,Olive,Rosemary and Thyme Foccac...   662315
# Truffle Linguine With Tomatoes and Pancetta          663885
# Coconut Flour Muffins                               1095713
#
# [150 rows x 2 columns]

# %% [markdown]
# #### Delete the columns that have null values == 141

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0                      0
# vegetarian                      0
# glutenFree                      0
# dairyFree                       0
# veryHealthy                     0
#                              ...
# CalciumpercentOfDailyNeed       8
# AlcoholAmount                 129
# AlcoholpercentOfDailyNeed     129
# CaffeineAmount                141
# CaffeinepercentOfDailyNeed    141
# Length: 78, dtype: int64

# %%
cols = ['CaffeineAmount', 'CaffeinepercentOfDailyNeed']
df1 = df.drop(cols, axis=1)

# %%
df1.isnull().sum()
# Out:
# Unnamed: 0                       0
# vegetarian                       0
# glutenFree                       0
# dairyFree                        0
# veryHealthy                      0
#                               ...
# VitaminB1percentOfDailyNeed      7
# CalciumAmount                    8
# CalciumpercentOfDailyNeed        8
# AlcoholAmount                  129
# AlcoholpercentOfDailyNeed      129
# Length: 76, dtype: int64

# %% [markdown]
# #### Print the title of the recipes that are vegetarian == TRUE and glutenFree == True

# %%
df1.groupby(['title'], as_index=True)['vegetarian','glutenFree'].count()
# Out:
# <ipython-input-17-f7def8d5755b>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   df1.groupby(['title'], as_index=True)['vegetarian','glutenFree'].count()
#                                                    vegetarian  glutenFree
# title
# Allergy-Free Stuffed Portobello Mushrooms                   1           1
# Almond Butter and Chocolate Squares                         1           1
# Amaretto Chocolate Cookies                                  1           1
# Asian Salmon Burgers With Tangy Ginger Lime Sauce           1           1
# Bad Boy" Giant Double Chocolate Cookies                     1           1
# ...                                                       ...         ...
# Turkey Burgers with Slaw                                    1           1
# Vegan Chana Masala Curry                                    1           1
# Vegetable Cheddar Quiche                                    1           1
# White Chocolate Raspberry Brie Cups                         1           1
# Yorkshire Pudding                                           1           1
#
# [149 rows x 2 columns]

# %%
print(df1[['vegetarian', 'glutenFree']] == 'True')
# Out:
#                                                    vegetarian  glutenFree
# title
# Banana Blueberry Pancakes                               False       False
# Basil and Orange Confit Compound Butter                 False       False
# Black Bottom Banana Bars                                False       False
# The Best Raw Chocolate Chip Cookies                     False       False
# Mediterranean Spinach Artichoke Dip                     False       False
# ...                                                       ...         ...
# Chicken Sausage, White Bean and Cabbage Soup            False       False
# Pinot Noir Brownies                                     False       False
# Cauliflower Chickpea Stew                               False       False
# Sautéed Balsamic Green Beans With Cherry Tomatoes       False       False
# Indian-Style Dill and Turmeric Potato Salad             False       False
#
# [150 rows x 2 columns]

# %% [markdown]
# #### How many vegan recipes are there (Vegan = Vegetarian and dairy free)?

# %%
#https://www.youtube.com/watch?v=ipoSjrN0oh0

df2.groupby(['vegetarian'])[['dairyFree']].count()
# Out:
#             dairyFree
# vegetarian
# False              84
# True               66

# %% [markdown]
# #### Compare the average amount of Vitamin B12 for the vegan and non-vegan recipes. How reliable are the results?

# %%
mean = df1.groupby(['VitaminB12Amount'])['vegetarian','dairyFree','glutenFree','veryHealthy'].mean()
mean
# Out:
# <ipython-input-32-54ab68d8cceb>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   mean = df1.groupby(['VitaminB12Amount'])['vegetarian','dairyFree','glutenFree','veryHealthy'].mean()
#                   vegetarian  dairyFree  glutenFree  veryHealthy
# VitaminB12Amount
# 0.06                0.000000   0.500000         0.5          0.0
# 0.07                1.000000   0.000000         0.0          0.0
# 0.08                1.000000   0.000000         0.0          0.0
# 0.10                0.333333   0.333333         0.0          0.0
# 0.11                1.000000   0.000000         0.0          0.0
# ...                      ...        ...         ...          ...
# 4.20                0.000000   0.000000         1.0          1.0
# 4.64                0.000000   0.000000         0.0          0.0
# 5.00                0.000000   0.000000         0.0          0.0
# 5.50                0.000000   0.000000         1.0          0.0
# 5.76                0.000000   0.000000         0.0          0.0
#
# [65 rows x 4 columns]

# %% [markdown]
