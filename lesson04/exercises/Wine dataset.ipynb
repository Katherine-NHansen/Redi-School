# %%
# Import pandas
import pandas as pd

# Read in filename and set the index: election
df = pd.read_csv("data\\wine.csv", index_col =1)

df
# Out:
#           Unnamed: 0                                        description  \
# country
# Italy              0  Aromas include tropical fruit, broom, brimston...
# Portugal           1  This is ripe and fruity, a wine that is smooth...
# US                 2  Tart and snappy, the flavors of lime flesh and...
# US                 3  Pineapple rind, lemon pith and orange blossom ...
# US                 4  Much like the regular bottling from 2012, this...
# ...              ...                                                ...
# Germany       129966  Notes of honeysuckle and cantaloupe sweeten th...
# US            129967  Citation is given as much as a decade of bottl...
# France        129968  Well-drained gravel soil gives this wine its c...
# France        129969  A dry style of Pinot Gris, this is crisp with ...
# France        129970  Big, rich and off-dry, this is powered by inte...
#
#                                      designation  points  price  \
# country
# ...

# %%
# Create a separate dataframe with the columns ['winery', 'price', 'points']: results
results = df[['winery', 'price', 'points']]
results
# Out:
#                                             winery  price  points
# country
# Italy                                      Nicosia    NaN      87
# Portugal                       Quinta dos Avidagos   15.0      87
# US                                       Rainstorm   14.0      87
# US                                      St. Julian   13.0      87
# US                                    Sweet Cheeks   65.0      87
# ...                                            ...    ...     ...
# Germany   Dr. H. Thanisch (Erben Müller-Burggraef)   28.0      90
# US                                        Citation   75.0      90
# France                             Domaine Gresser   30.0      90
# France                        Domaine Marcel Deiss   32.0      90
# France                            Domaine Schoffit   21.0      90
#
# [129971 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'description', 'designation', 'points', 'price',
#        'province', 'region_1', 'region_2', 'taster_name',
#        'taster_twitter_handle', 'title', 'variety', 'winery'],
#       dtype='object')

# %%
# Print the output of results.head()
print(results.head())
# Out:
#                 winery  price  points   country
# 0              Nicosia    NaN      87     Italy
# 1  Quinta dos Avidagos   15.0      87  Portugal
# 2            Rainstorm   14.0      87        US
# 3           St. Julian   13.0      87        US
# 4         Sweet Cheeks   65.0      87        US

# %% [markdown]
# # Slincing DataFrames

# %%
df.loc[:, 'country': 'price']
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price
# 0                                 Vulkà Bianco      87    NaN
# ...

# %% [markdown]
# # df.loc['Riesling': 'Pinot Noir', ['points','price']] (question)

# %%
#row (2) and 5 and column (1) to the last columns

df.iloc[2:5,1:]
# Out:
#                                          description  \
# 2  Tart and snappy, the flavors of lime flesh and...
# 3  Pineapple rind, lemon pith and orange blossom ...
# 4  Much like the regular bottling from 2012, this...
#
#                           designation  points  price  province  \
# 2                                 NaN      87   14.0    Oregon
# 3                Reserve Late Harvest      87   13.0  Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0    Oregon
#
#               region_1           region_2         taster_name  \
# 2    Willamette Valley  Willamette Valley        Paul Gregutt
# 3  Lake Michigan Shore                NaN  Alexander Peartree
# 4    Willamette Valley  Willamette Valley        Paul Gregutt
#
#   taster_twitter_handle                                              title  \
# 2           @paulgwine       Rainstorm 2013 Pinot Gris (Willamette Valley)
# 3                   NaN  St. Julian 2013 Reserve Late Harvest Riesling ...
# ...

# %%
# 0 column 2

df.iloc[[0,2,4], 0:2]
# Out:
#   country                                        description
# 0   Italy  Aromas include tropical fruit, broom, brimston...
# 2      US  Tart and snappy, the flavors of lime flesh and...
# 4      US  Much like the regular bottling from 2012, this...

# %%
#A series by column name
#type(df[''description''])
#pandas.core.series.Series

df['description']
# Out:
# country
# Italy       Aromas include tropical fruit, broom, brimston...
# Portugal    This is ripe and fruity, a wine that is smooth...
# US          Tart and snappy, the flavors of lime flesh and...
# US          Pineapple rind, lemon pith and orange blossom ...
# US          Much like the regular bottling from 2012, this...
#                                   ...
# Germany     Notes of honeysuckle and cantaloupe sweeten th...
# US          Citation is given as much as a decade of bottl...
# France      Well-drained gravel soil gives this wine its c...
# France      A dry style of Pinot Gris, this is crisp with ...
# France      Big, rich and off-dry, this is powered by inte...
# Name: description, Length: 129971, dtype: object

# %%
#A DataFrame w/single column
#type(df[''description''])
#pandas.core.frame.Dataframe
df[['country','description']]
# Out:
#          country                                        description
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
# [129971 rows x 2 columns]

# %% [raw]
# """""# Slice the row labels 'Perry' to 'Potter': p_counties
# country = df.loc['US':'Portugal':,]
#
# # Print the p_counties DataFrame
# print(country)
#
# # Slice the row labels 'Potter' to 'Perry' in reverse order: p_counties_rev
# country_rev = df.loc['US':'Portugal':-1]
#
# # Print the p_counties_rev DataFrame
# print(country_rev)""""

# %%
# Slice the columns from the starting column to 'Obama': left_columns
left_columns = election.loc[:, :'designation']

# Print the output of left_columns.head()
print(left_columns.head())
# Out:
#           Unnamed: 0                                        description  \
# country
# Italy              0  Aromas include tropical fruit, broom, brimston...
# Portugal           1  This is ripe and fruity, a wine that is smooth...
# US                 2  Tart and snappy, the flavors of lime flesh and...
# US                 3  Pineapple rind, lemon pith and orange blossom ...
# US                 4  Much like the regular bottling from 2012, this...
#
#                                  designation
# country
# Italy                           Vulkà Bianco
# Portugal                            Avidagos
# US                                       NaN
# US                      Reserve Late Harvest
# US        Vintner's Reserve Wild Child Block

# %%
# Slice the columns from 'variety' to 'winery': middle_columns
middle_columns = df.loc[:, 'variety':'winery']

# Print the output of middle_columns.head()
print(middle_columns.head())
# Out:
#           variety               winery
# 0     White Blend              Nicosia
# 1  Portuguese Red  Quinta dos Avidagos
# 2      Pinot Gris            Rainstorm
# 3        Riesling           St. Julian
# 4      Pinot Noir         Sweet Cheeks

# %%
# Slice the columns from 'winery' to the end: 'right_columns'
right_columns = df.loc[:, 'winery':]

# Print the output of right_columns.head()
print(right_columns.head())
# Out:
#                 winery
# 0              Nicosia
# 1  Quinta dos Avidagos
# 2            Rainstorm
# 3           St. Julian
# 4         Sweet Cheeks

# %%
df.columns
# Out:
# Index(['country', 'description', 'designation', 'points', 'price', 'province',
#        'region_1', 'region_2', 'taster_name', 'taster_twitter_handle', 'title',
#        'variety', 'winery'],
#       dtype='object')

# %%
# Create the list of row labels: rows
rows = ['US','Germany','Chile']
rows
# Out:
# ['US', 'Germany', 'Chile']

# %%
# Create the list of column labels: cols
cols = ['price', 'winery','variety']

# %%
# Create the new DataFrame: three_counties
three_counties = df.loc[rows, cols]

# %%
# Print the three_counties DataFrame
print(three_counties)
# Out:
#          price              winery                   variety
# country
# US        14.0           Rainstorm                Pinot Gris
# US        13.0          St. Julian                  Riesling
# US        65.0        Sweet Cheeks                Pinot Noir
# US        19.0  Kirkland Signature        Cabernet Sauvignon
# US        34.0    Louis M. Martini        Cabernet Sauvignon
# ...        ...                 ...                       ...
# Chile     11.0         Oveja Negra  Cabernet Sauvignon-Syrah
# Chile     13.0           Apaltagua                Pinot Noir
# Chile     30.0       Concha y Toro           Sauvignon Blanc
# Chile     18.0        Santa Alicia                 Red Blend
# Chile     10.0      Santa Carolina           Sauvignon Blanc
#
# [78516 rows x 3 columns]

# %% [markdown]
# # Filtering DataFrames

# %%
# df.price   > 60

# %%
#Filter

df[df.points <= 80]
# Out:
#           country                                        description  \
# 344         Chile  Aromas of pumpkin, squash and corn chips are s...
# 3640     Portugal  Aromas of strawberry sherbet are followed by s...
# 3641        Chile  Fluffy, sweet aromas of peach, pear and vanill...
# 4556        Italy  There's a thorny, almost raw quality of fruit ...
# 4557        Spain  With dusty, candied aromas, the bouquet on thi...
# ...           ...                                                ...
# 128258         US  This Chardonnay-Viognier blend is slightly swe...
# 128259         US  While there's some nice, honest fruit here, it...
# 128260         US  Banana, clove and orange peel open for this sw...
# 128261         US  Short and slightly sweet, there's nutty overto...
# 128262  Argentina  Smells like crushed vitamins, iron and mineral...
#
#                  designation  points  price          province  \
# 344             Gran Reserva      80   19.0      Leyda Valley
# ...

# %%
enough_points = df.points > 60
df[enough_points]
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# 2             US  Tart and snappy, the flavors of lime flesh and...
# 3             US  Pineapple rind, lemon pith and orange blossom ...
# 4             US  Much like the regular bottling from 2012, this...
# ...          ...                                                ...
# 129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967        US  Citation is given as much as a decade of bottl...
# 129968    France  Well-drained gravel soil gives this wine its c...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                                    designation  points  price  \
# 0                                 Vulkà Bianco      87    NaN
# ...

# %%
#Com

# %%
df1 = df.copy()

# %%
#Select columns with all nonzeros
df1.loc[:, df1.all()]
# Out:
#                                                 description  \
# country
# Italy     Aromas include tropical fruit, broom, brimston...
# Portugal  This is ripe and fruity, a wine that is smooth...
# US        Tart and snappy, the flavors of lime flesh and...
# US        Pineapple rind, lemon pith and orange blossom ...
# US        Much like the regular bottling from 2012, this...
# ...                                                     ...
# Germany   Notes of honeysuckle and cantaloupe sweeten th...
# US        Citation is given as much as a decade of bottl...
# France    Well-drained gravel soil gives this wine its c...
# France    A dry style of Pinot Gris, this is crisp with ...
# France    Big, rich and off-dry, this is powered by inte...
#
#                                      designation  points  price  \
# country
# Italy                               Vulkà Bianco      87    NaN
# Portugal                                Avidagos      87   15.0
# ...

# %%
df1.loc[:, df1.any()]
# Out:
#           Unnamed: 0                                        description  \
# country
# Italy              0  Aromas include tropical fruit, broom, brimston...
# Portugal           1  This is ripe and fruity, a wine that is smooth...
# US                 2  Tart and snappy, the flavors of lime flesh and...
# US                 3  Pineapple rind, lemon pith and orange blossom ...
# US                 4  Much like the regular bottling from 2012, this...
# ...              ...                                                ...
# Germany       129966  Notes of honeysuckle and cantaloupe sweeten th...
# US            129967  Citation is given as much as a decade of bottl...
# France        129968  Well-drained gravel soil gives this wine its c...
# France        129969  A dry style of Pinot Gris, this is crisp with ...
# France        129970  Big, rich and off-dry, this is powered by inte...
#
#                                      designation  points  price  \
# country
# ...

# %%
#Slect columns with anu NaNs
df.loc[:, df.isnull().any()]
# Out:
#                                      designation  price           province  \
# country
# Italy                               Vulkà Bianco    NaN  Sicily & Sardinia
# Portugal                                Avidagos   15.0              Douro
# US                                           NaN   14.0             Oregon
# US                          Reserve Late Harvest   13.0           Michigan
# US            Vintner's Reserve Wild Child Block   65.0             Oregon
# ...                                          ...    ...                ...
# Germany   Brauneberger Juffer-Sonnenuhr Spätlese   28.0              Mosel
# US                                           NaN   75.0             Oregon
# France                                     Kritt   30.0             Alsace
# France                                       NaN   32.0             Alsace
# France             Lieu-dit Harth Cuvée Caroline   21.0             Alsace
#
# ...

# %%
#Select columns without NaNs
df.loc[:, df.notnull().all()]
# Out:
#           Unnamed: 0                                        description  \
# country
# Italy              0  Aromas include tropical fruit, broom, brimston...
# Portugal           1  This is ripe and fruity, a wine that is smooth...
# US                 2  Tart and snappy, the flavors of lime flesh and...
# US                 3  Pineapple rind, lemon pith and orange blossom ...
# US                 4  Much like the regular bottling from 2012, this...
# ...              ...                                                ...
# Germany       129966  Notes of honeysuckle and cantaloupe sweeten th...
# US            129967  Citation is given as much as a decade of bottl...
# France        129968  Well-drained gravel soil gives this wine its c...
# France        129969  A dry style of Pinot Gris, this is crisp with ...
# France        129970  Big, rich and off-dry, this is powered by inte...
#
#           points                                              title  \
# country
# ...

# %%
#Drop rows with any Nans
df.dropna(how='any')
# Out:
#          Unnamed: 0                                        description  \
# country
# US                4  Much like the regular bottling from 2012, this...
# US               10  Soft, supple plum envelopes an oaky structure ...
# US               23  This wine from the Geneseo district offers aro...
# US               25  Oak and earth intermingle around robust aromas...
# US               35  As with many of the Erath 2010 vineyard design...
# ...             ...                                                ...
# US           129919  This ripe, rich, almost decadently thick wine ...
# US           129926  This pure Syrah from Reininger's estate vineya...
# US           129945  Hailing from one of the more popular vineyards...
# US           129949  There's no bones about the use of oak in this ...
# US           129950  This opens with herbaceous dollops of thyme an...
#
#                                 designation  points  price    province  \
# country
# ...

# %%
df.variety[df.points > 70]
# Out:
# country
# Italy          White Blend
# Portugal    Portuguese Red
# US              Pinot Gris
# US                Riesling
# US              Pinot Noir
#                  ...
# Germany           Riesling
# US              Pinot Noir
# France      Gewürztraminer
# France          Pinot Gris
# France      Gewürztraminer
# Name: variety, Length: 129971, dtype: object

# %%
df.price[df.points > 70] += 100
# Out:
# <ipython-input-136-e0d23e9614ca>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.price[df.points > 70] += 100

# %%
# Create the boolean array: high_price
high_price = df['price'] > 100

# %%
# Filter the election DataFrame with the high_price array: high_price_df
high_price_df = df.loc[high_price]

# %%
# Print the high_turnout_results DataFrame
print(high_price_df)
# Out:
#           Unnamed: 0                                        description  \
# country
# Portugal           1  This is ripe and fruity, a wine that is smooth...
# US                 2  Tart and snappy, the flavors of lime flesh and...
# US                 3  Pineapple rind, lemon pith and orange blossom ...
# US                 4  Much like the regular bottling from 2012, this...
# Spain              5  Blackberry and raspberry aromas show a typical...
# ...              ...                                                ...
# Germany       129966  Notes of honeysuckle and cantaloupe sweeten th...
# US            129967  Citation is given as much as a decade of bottl...
# France        129968  Well-drained gravel soil gives this wine its c...
# France        129969  A dry style of Pinot Gris, this is crisp with ...
# France        129970  Big, rich and off-dry, this is powered by inte...
#
#                                      designation  points  price  \
# country
# ...

# %%
# Import numpy
import numpy as np

# %%
# Create the boolean array: too_close
too_close = df1['price'] < 1

# %%
too_close
# Out:
# country
# Italy       False
# Portugal    False
# US          False
# US          False
# US          False
#             ...
# Germany     False
# US          False
# France      False
# France      False
# France      False
# Name: price, Length: 129971, dtype: bool

# %%
# Assign np.nan to the 'winery ' column where the results were too close to call
df1.loc[too_close, 'variety'] = np.nan

# %%
# Print the output ofdf1.info()
print(df1.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 129971 entries, Italy to France
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count   Dtype
# ---  ------                 --------------   -----
#  0   Unnamed: 0             129971 non-null  int64
#  1   description            129971 non-null  object
#  2   designation            92506 non-null   object
#  3   points                 129971 non-null  int64
#  4   price                  120975 non-null  float64
#  5   province               129908 non-null  object
#  6   region_1               108724 non-null  object
#  7   region_2               50511 non-null   object
#  8   taster_name            103727 non-null  object
#  9   taster_twitter_handle  98758 non-null   object
#  10  title                  129971 non-null  object
#  11  variety                129970 non-null  object
#  12  winery                 129971 non-null  object
# dtypes: float64(1), int64(2), object(10)
# memory usage: 15.9+ MB
# None

# %%
# Select the 'age' and 'cabin' columns: df
df = df[['points','price']]
# Print the shape of df
print(df.shape)
# Out:
# (129971, 2)

# %%
# Drop rows in df with how='any' and print the shape
print(df.dropna(how='any').shape)
# Out:
# (120975, 2)

# %%
# Drop rows in df with how='all' and print the shape
print(df.dropna(how='all').shape)
# Out:
# (129971, 2)

# %%
# Drop columns in titanic with less than 1000 non-missing values
print(df.dropna(thresh=1000, axis=1).info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 129971 entries, Italy to France
# Data columns (total 2 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   points  129971 non-null  int64
#  1   price   120975 non-null  float64
# dtypes: float64(1), int64(1)
# memory usage: 3.0+ MB
# None

# %% [markdown]
# # Transforming DataFrame

# %%
import numpy as np

# %%
#convert to dozens unit
np.floor_divide(df, 12)
# Out:
#           points  price
# country
# Italy          7    NaN
# Portugal       7    1.0
# US             7    1.0
# US             7    1.0
# US             7    5.0
# ...          ...    ...
# Germany        7    2.0
# US             7    6.0
# France         7    2.0
# France         7    2.0
# France         7    1.0
#
# [129971 rows x 2 columns]

# %%
df['dozens_of_points'] = df.points.floordiv(12)
df
# Out:
# <ipython-input-222-d9574e3eabf2>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['dozens_of_points'] = df.points.floordiv(12)
#           points  price  dozens_of_points
# country
# Italy         87    NaN                 7
# Portugal      87   15.0                 7
# US            87   14.0                 7
# US            87   13.0                 7
# US            87   65.0                 7
# ...          ...    ...               ...
# Germany       90   28.0                 7
# US            90   75.0                 7
# France        90   30.0                 7
# France        90   32.0                 7
# France        90   21.0                 7
#
# [129971 rows x 3 columns]

# %%
#working with string values

df.index =df.index.str.upper()
df
# Out:
#           points  price  dozens_of_points
# country
# ITALY         87    NaN                 7
# PORTUGAL      87   15.0                 7
# US            87   14.0                 7
# US            87   13.0                 7
# US            87   65.0                 7
# ...          ...    ...               ...
# GERMANY       90   28.0                 7
# US            90   75.0                 7
# FRANCE        90   30.0                 7
# FRANCE        90   32.0                 7
# FRANCE        90   21.0                 7
#
# [129971 rows x 3 columns]

# %% [markdown]
# # df1.index = df1.index.map(str.lower)
# df1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 129971 entries, ITALY to FRANCE
# Data columns (total 3 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   points            129971 non-null  int64
#  1   price             120975 non-null  float64
#  2   dozens_of_points  129971 non-null  int64
# dtypes: float64(1), int64(2)
# memory usage: 4.0+ MB

# %%
# Apply the function over 'Mean TemperatureF' and 'Mean Dew PointF': df_celsius
df_celsius = df[['points','price']].apply()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-234-e7051f0c40fc> in <module>
#       1 # Apply the function over 'Mean TemperatureF' and 'Mean Dew PointF': df_celsius
# ----> 2 df_celsius = df[['points','price']].apply(valor)
#
# NameError: name 'valor' is not defined
