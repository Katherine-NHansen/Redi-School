# %%
import http.client

conn = http.client.HTTPSConnection("spoonacular-recipe-food-nutrition-v1.p.rapidapi.com")

headers = {
    'x-rapidapi-key': "07479269ccmsh38e9e1c0c223362p1b8094jsn4070889b9973",
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com"
    }

conn.request("GET", "/recipes/4632/summary", headers=headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# {"id":4632,"title":"Soy-and-Ginger-Glazed Salmon with Udon Noodles","summary":"Soy-and-Ginger-Glazed Salmon with Udon Noodles takes around <b>1 hour and 35 minutes</b> from beginning to end. This dairy free and pescatarian recipe serves 4 and costs <b>$5.91 per serving</b>. This main course has <b>552 calories</b>, <b>48g of protein</b>, and <b>17g of fat</b> per serving. 1 person has made this recipe and would make it again. A mixture of spinach, salmon fillets, sugar, and a handful of other ingredients are all it takes to make this recipe so scrumptious. It is brought to you by Food and Wine. All things considered, we decided this recipe <b>deserves a spoonacular score of 92%</b>. This score is spectacular. If you like this recipe, take a look at these similar recipes: <a href=\"https://spoonacular.com/recipes/soy-and-ginger-glazed-salmon-with-udon-noodles-1360935\">Soy-and-Ginger-Glazed Salmon with Udon Noodles</a>, <a href=\"https://spoonacular.com/recipes/soy-and-ginger-glazed-s
# ...

# %%
import http.client

conn = http.client.HTTPSConnection("spoonacular-recipe-food-nutrition-v1.p.rapidapi.com")

payload = "ingredientList=3%20oz%20flour&servings=2&showBacklink=true&defaultCss=true"

headers = {
    'content-type': "application/x-www-form-urlencoded",
    'accept': "text/html",
    'x-rapidapi-key': "07479269ccmsh38e9e1c0c223362p1b8094jsn4070889b9973",
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com"
    }

conn.request("POST", "/recipes/visualizeNutrition", payload, headers)

res = conn.getresponse()
data = res.read()

print(data.decode("utf-8"))
# Out:
# <style type="text/css">.spoonacular-salmon{color:#e76182}
# .spoonacular-blue{color:#269fca}
# .spoonacular-quickview{font-size:14px;display:inline-block;padding:5px 10px;border:1px solid #333;margin-right:6px;margin-bottom:6px;font-weight:bold}
# .spoonacular-caption{font-weight:bold;margin-top:12px;font-size:16px;margin-bottom:6px}
# .spoonacular-nutrition-visualization-bar{display:inline-block;height:12px;max-width:calc(100% - 70px);max-width:-webkit-calc(100% - 70px);max-width:-moz-calc(100% - 70px);max-width:-o-calc(100% - 70px)}
# .spoonacular-nutrition-visualization-bar.spoonacular-salmon{background-color:#e76182}
# .spoonacular-nutrition-visualization-bar.spoonacular-blue{background-color:#269fca}
# .spoonacular-nutrition-visualization-bar-number{display:inline-block;margin-left:12px}
# .spoonacular-nutrient-name{display:inline-block;width:114px;font-size:14px}
# .spoonacular-nutrient-value{display:inline-block;width:75px;font-size:14px}
# ...

# %%
import requests

url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/visualizeNutrition"

payload = "ingredientList=3%20oz%20flour&servings=2&showBacklink=true&defaultCss=true"
headers = {
    'content-type': "application/x-www-form-urlencoded",
    'accept': "text/html",
    'x-rapidapi-key': "07479269ccmsh38e9e1c0c223362p1b8094jsn4070889b9973",
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com"
    }

response = requests.request("POST", url, data=payload, headers=headers)

print(response.text)
# Out:
# <style type="text/css">.spoonacular-salmon{color:#e76182}
# .spoonacular-blue{color:#269fca}
# .spoonacular-quickview{font-size:14px;display:inline-block;padding:5px 10px;border:1px solid #333;margin-right:6px;margin-bottom:6px;font-weight:bold}
# .spoonacular-caption{font-weight:bold;margin-top:12px;font-size:16px;margin-bottom:6px}
# .spoonacular-nutrition-visualization-bar{display:inline-block;height:12px;max-width:calc(100% - 70px);max-width:-webkit-calc(100% - 70px);max-width:-moz-calc(100% - 70px);max-width:-o-calc(100% - 70px)}
# .spoonacular-nutrition-visualization-bar.spoonacular-salmon{background-color:#e76182}
# .spoonacular-nutrition-visualization-bar.spoonacular-blue{background-color:#269fca}
# .spoonacular-nutrition-visualization-bar-number{display:inline-block;margin-left:12px}
# .spoonacular-nutrient-name{display:inline-block;width:114px;font-size:14px}
# .spoonacular-nutrient-value{display:inline-block;width:75px;font-size:14px}
# ...

# %%
import requests

url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/queries/analyze"

querystring = {"q":"salmon with fusilli and no nuts"}

headers = {
    'x-rapidapi-key': "07479269ccmsh38e9e1c0c223362p1b8094jsn4070889b9973",
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"ingredients":[{"name":"fusilli","include":true,"image":"fusilli.jpg"},{"name":"nuts mixed","include":false,"image":"nuts-mixed.jpg"}],"dishes":[{"name":"salmon","image":"https://spoonacular.com/cdn/ingredients_100x100/salmon.png"}],"modifiers":[],"cuisines":[]}

# %%
import requests

url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/food/detect"

payload = "text=I%20like%20to%20eat%20delicious%20tacos.%20Only%20cheeseburger%20with%20cheddar%20are%20better%20than%20that.%20But%20then%20again%2C%20pizza%20with%20pepperoni%2C%20mushrooms%2C%20and%20tomatoes%20is%20so%20good!"
headers = {
    'content-type': "application/x-www-form-urlencoded",
    'x-rapidapi-key': "07479269ccmsh38e9e1c0c223362p1b8094jsn4070889b9973",
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com"
    }

response = requests.request("POST", url, data=payload, headers=headers)

print(response.text)
# Out:
# {"annotations":[{"annotation":"cheeseburger","tag":"dish","image":"https://spoonacular.com/menuItemImages/cheeseburger.jpg"},{"annotation":"pepperoni","tag":"ingredient","image":"https://spoonacular.com/cdn/ingredients_100x100/pepperoni.png"},{"annotation":"mushrooms","tag":"ingredient","image":"https://spoonacular.com/cdn/ingredients_100x100/mushrooms.png"},{"annotation":"tomatoes","tag":"ingredient","image":"https://spoonacular.com/cdn/ingredients_100x100/tomato.png"},{"annotation":"cheddar","tag":"ingredient","image":"https://spoonacular.com/cdn/ingredients_100x100/cheddar-cheese.png"},{"annotation":"tacos","tag":"dish","image":"https://spoonacular.com/menuItemImages/taco-isolated.jpg"},{"annotation":"pizza","tag":"dish","image":"https://spoonacular.com/menuItemImages/cheese-pizza.png"}],"processedInMs":17}

# %%
import requests

url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/informationBulk"

querystring = {"ids":"456,987,321"}

headers = {
    'x-rapidapi-key': "07479269ccmsh38e9e1c0c223362p1b8094jsn4070889b9973",
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers, params=querystring)

print(response.text)
# Out:
# {"status":"failure", "code":400,"message":"One of the recipe ids could not be parsed correctly."}

# %%
import requests

url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/food/trivia/random"

headers = {
    'x-rapidapi-key': "07479269ccmsh38e9e1c0c223362p1b8094jsn4070889b9973",
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# {"text":"A row of corn always has an even number."}

# %%
import requests

url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/food/products/22347"

headers = {
    'x-rapidapi-key': "07479269ccmsh38e9e1c0c223362p1b8094jsn4070889b9973",
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# {"id":22347,"title":"SNICKERS Minis Size Chocolate Candy Bars Variety Mix 10.5-oz. Bag","price":324.0,"likes":0,"badges":["msg_free","no_artificial_colors","no_artificial_flavors","no_artificial_ingredients","gluten_free"],"importantBadges":["no_artificial_flavors","no_artificial_colors","no_artificial_ingredients","gluten_free","msg_free"],"nutrition":{"nutrients":[{"name":"Calcium","title":"Calcium","amount":40.0,"unit":"mg","percentOfDailyNeeds":4.0},{"name":"Carbohydrates","title":"Carbohydrates","amount":25.0,"unit":"g","percentOfDailyNeeds":8.33},{"name":"Cholesterol","title":"Cholesterol","amount":5.0,"unit":"mg","percentOfDailyNeeds":1.67},{"name":"Calories","title":"Calories","amount":180.0,"unit":"kcal","percentOfDailyNeeds":9.0},{"name":"Fat","title":"Fat","amount":8.0,"unit":"g","percentOfDailyNeeds":12.31},{"name":"Saturated Fat","title":"Saturated Fat","amount":3.5,"unit":"g","percentOfDailyNeeds":21.88},{"name":"Trans Fat","title":"Trans Fat","amount":0.0,"unit":"g","p
# ...

# %%
import requests

url = "https://spoonacular-recipe-food-nutrition-v1.p.rapidapi.com/recipes/479101/information"

headers = {
    'x-rapidapi-key': "07479269ccmsh38e9e1c0c223362p1b8094jsn4070889b9973",
    'x-rapidapi-host': "spoonacular-recipe-food-nutrition-v1.p.rapidapi.com"
    }

response = requests.request("GET", url, headers=headers)

print(response.text)
# Out:
# {"vegetarian":false,"vegan":false,"glutenFree":false,"dairyFree":true,"veryHealthy":false,"cheap":false,"veryPopular":false,"sustainable":false,"weightWatcherSmartPoints":9,"gaps":"no","lowFodmap":false,"preparationMinutes":10,"cookingMinutes":10,"aggregateLikes":225,"spoonacularScore":96.0,"healthScore":46.0,"creditsText":"Feed Me Phoebe","sourceName":"Feed Me Phoebe","pricePerServing":199.25,"extendedIngredients":[{"id":18079,"aisle":"Pasta and Rice","image":"breadcrumbs.jpg","consistency":"solid","name":"breadcrumbs","nameClean":"breadcrumbs","original":"1/2 cup fresh breadcrumbs (I used gluten-free!)","originalString":"1/2 cup fresh breadcrumbs (I used gluten-free!)","originalName":"fresh breadcrumbs (I used gluten-free!)","amount":0.5,"unit":"cup","meta":["fresh","(I used gluten-free!)"],"metaInformation":["fresh","(I used gluten-free!)"],"measures":{"us":{"amount":0.5,"unitShort":"cups","unitLong":"cups"},"metric":{"amount":118.294,"unitShort":"ml","unitLong":"milliliters"}}},{
# ...
